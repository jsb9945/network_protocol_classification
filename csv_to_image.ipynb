# %%
import pandas as pd
# from dnslib import DNSRecord
import ast
import math
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
'''DNS_DATA = pd.read_csv('payload_csv/dns_payloads.csv')
HTTP_DATA = pd.read_csv('payload_csv/http_payloads.csv')
MQTT_DATA = pd.read_csv('payload_csv/mqtt_payloads.csv')'''
# Out:
# "DNS_DATA = pd.read_csv('payload_csv/dns_payloads.csv')\nHTTP_DATA = pd.read_csv('payload_csv/http_payloads.csv')\nMQTT_DATA = pd.read_csv('payload_csv/mqtt_payloads.csv')"

# %%
PROTOCOL_LIST = ['dns', 'http', 'mqtt']

# %%
fixed_image_size = 5
max_data_length = 25

# %%
def grayscale_to_rgb(value):
    r = value % 256
    g = (value * 2) % 256
    b = (value * 3) % 256
    return r, g, b

# %%
def sliding_window_to2D(data, window_size=4, step_size=4):

    windows = [data[i:i+window_size] for i in range(0, len(data), step_size)]
    
    # 각 윈도우를 1D 배열로 평탄화 (패딩 포함)
    flat_values = [val for window in windows for val in window]
    
    # 고정된 이미지 크기로 패딩 추가
    padded_values = flat_values + [0] * (fixed_image_size ** 2 - len(flat_values))
    
    # 고정된 크기의 2D 배열로 변환 (10x10)
    pixel_matrix = np.array(padded_values).reshape(fixed_image_size, fixed_image_size)

    rgb_matrix = np.zeros((fixed_image_size, fixed_image_size, 3), dtype=np.uint8)  # (R, G, B) 각각 8비트
    
    for i in range(fixed_image_size):
        for j in range(fixed_image_size):
            r, g, b = grayscale_to_rgb(pixel_matrix[i, j])
            rgb_matrix[i, j] = [r, g, b]
    
    return rgb_matrix

# %%
def data_read_pre(data_df, idx):
    data = data_df['Payload(Bytes)'][i]

    if len(data) > max_data_length:
        data = data[:max_data_length]
    else:
        data = data + ' ' * (max_data_length - len(data))

    ascii_values = [ord(c) for c in data]

    return ascii_values

# %%
# 현재 찐 코드

import os
import pandas as pd
import matplotlib.pyplot as plt

start_idx = 0
MAX_IMAGES_PER_PROTOCOL = 10000  # 프로토콜당 최대 처리할 이미지 개수
MAX_IMAGES_PER_FILE = 0

all_image_data = []

for class_idx, protocol in enumerate(PROTOCOL_LIST):
    # 스플릿된 CSV 파일을 처리하는 코드
    chunk_idx = 1  # 청크 인덱스 초기화
    
    # 프로토콜 별 이미지 데이터 저장 리스트 초기화
    image_data = []
    
    total_images_processed = 0
    
    while True:
        input_file = f'payload_csv/split/{protocol}/{protocol}_{chunk_idx}.csv'  # 스플릿된 CSV 파일 경로
        
        if not os.path.exists(input_file):  # 파일이 존재하지 않으면 종료
            print(f"File not found: {input_file}")
            break

        data_df = pd.read_csv(input_file)  # CSV 파일 읽기
        print(f"Processing {input_file}, Total rows: {len(data_df)}")

        # 폴더 생성 (클래스별 폴더)
        folder_name = f"train_data/protocol_{class_idx}"
        os.makedirs(folder_name, exist_ok=True)

        # 프로토콜마다 이미지 처리
        images_in_this_file = 0  # 이 파일에서 추출한 이미지 개수
        
        # 프로토콜이 'dns'일 때 모든 이미지를 처리
        # 프로토콜이 'dns'가 아닐 때는 5번째 파일만 처리
        if protocol == 'dns':
            # 모든 이미지 처리
            sample_indices = range(len(data_df))  # 모든 인덱스를 선택

            for i in sample_indices:
                if total_images_processed >= MAX_IMAGES_PER_PROTOCOL: 
                    print(f"Reached {MAX_IMAGES_PER_PROTOCOL} images for {protocol}")
                    break
                
                # 이미지 데이터 변환 및 저장 과정
                ascii_values = data_read_pre(data_df, i)
                rgb_matrix = sliding_window_to2D(ascii_values, window_size=8, step_size=8)

                # 새로운 figure 생성 (서브플롯을 사용하지 않음)
                fig, ax = plt.subplots(figsize=(3, 3))  # 각 이미지를 3x3 크기로 설정

                # 그레이스케일 이미지로 시각화
                im = ax.imshow(rgb_matrix, interpolation='nearest')
                ax.set_title(f"Payload {i+1}")  # 각 이미지에 타이틀 설정

                ax.set_xticks([])  # x축 눈금 제거
                ax.set_yticks([])

                # 이미지 경로 설정 및 저장
                image_path = os.path.join(folder_name, f"payload_image_{total_images_processed + 1}.png")
                plt.savefig(image_path, bbox_inches='tight', pad_inches=0.1)

                # figure 닫기 (메모리 절약)
                plt.close(fig)

                # 이미지 경로 및 클래스 번호 저장
                image_data.append({"image_path": image_path, "class": class_idx})
                
                # 원본 데이터 저장 (이미지 생성 시)
                payload_data = data_df.iloc[i].to_dict()  # 원본 데이터 가져오기
                payload_data["class"] = class_idx  # 클래스 추가

                # 이미지 경로와 원본 데이터 저장
                all_image_data.append(payload_data)
                
                total_images_processed += 1  # 이미지 처리 개수 증가
                images_in_this_file += 1  # 파일에서 추출한 이미지 개수 증가

        elif protocol != 'dns' and chunk_idx % 5 == 0:
            # 랜덤으로 100개 샘플링
            if protocol == 'http':
                MAX_IMAGES_PER_FILE = 500
            elif protocol == 'mqtt':
                MAX_IMAGES_PER_FILE = 125
            
            sample_indices = data_df.sample(n=min(MAX_IMAGES_PER_PROTOCOL - total_images_processed, MAX_IMAGES_PER_FILE, len(data_df)), random_state=42).index

            for i in sample_indices:
                if total_images_processed >= MAX_IMAGES_PER_PROTOCOL: 
                    print(f"Reached {MAX_IMAGES_PER_PROTOCOL} images for {protocol}")
                    break
                
                # 이미지 데이터 변환 및 저장 과정
                ascii_values = data_read_pre(data_df, i)
                rgb_matrix = sliding_window_to2D(ascii_values, window_size=8, step_size=8)

                # 새로운 figure 생성 (서브플롯을 사용하지 않음)
                fig, ax = plt.subplots(figsize=(3, 3))  # 각 이미지를 3x3 크기로 설정

                # 그레이스케일 이미지로 시각화
                im = ax.imshow(rgb_matrix, interpolation='nearest')
                ax.set_title(f"Payload {i+1}")  # 각 이미지에 타이틀 설정

                ax.set_xticks([])  # x축 눈금 제거
                ax.set_yticks([])

                # 이미지 경로 설정 및 저장
                image_path = os.path.join(folder_name, f"payload_image_{total_images_processed + 1}.png")
                plt.savefig(image_path, bbox_inches='tight', pad_inches=0.1)

                # figure 닫기 (메모리 절약)
                plt.close(fig)
                
                # 원본 데이터 저장 (이미지 생성 시)
                payload_data = data_df.iloc[i].to_dict()  # 원본 데이터 가져오기
                payload_data["class"] = class_idx  # 클래스 추가

                # 이미지 경로와 원본 데이터 저장
                all_image_data.append(payload_data)

                # 이미지 경로 및 클래스 번호 저장
                image_data.append({"image_path": image_path, "class": class_idx})
                
                total_images_processed += 1  # 이미지 처리 개수 증가
                images_in_this_file += 1  # 파일에서 추출한 이미지 개수 증가

        # 프로토콜별 CSV 파일로 저장
        if image_data:  # 이미지 데이터가 있을 경우에만 저장
            image_df = pd.DataFrame(image_data)
            csv_file_path = f"train_data/protocol_{class_idx}_image_class_info.csv"
            image_df.to_csv(csv_file_path, index=False)
            print(f"Saved {csv_file_path} with {len(image_data)} entries.")

        chunk_idx += 1  # 다음 청크로 이동

    # 각 프로토콜별 image_class_info CSV 파일의 행 수 출력
    csv_file_path = f"train_data/protocol_{class_idx}_image_class_info.csv"
    if os.path.exists(csv_file_path):
        saved_df = pd.read_csv(csv_file_path)
        print(f"{csv_file_path} has {len(saved_df)} entries.")

        
# 전체 원본 데이터와 클래스 정보를 하나의 CSV 파일로 저장
all_image_df = pd.DataFrame(all_image_data)
all_image_csv_path = 'train_data/all_payload_data_class_info.csv'
all_image_df.to_csv(all_image_csv_path, index=False)
print(f"Saved {all_image_csv_path} with {len(all_image_data)} entries.")
# Out:
# Processing payload_csv/split/dns/dns_1.csv, Total rows: 5000
# Saved train_data/protocol_0_image_class_info.csv with 5000 entries.
# Processing payload_csv/split/dns/dns_2.csv, Total rows: 5000
# Saved train_data/protocol_0_image_class_info.csv with 10000 entries.
# Processing payload_csv/split/dns/dns_3.csv, Total rows: 158
# Reached 10000 images for dns
# Saved train_data/protocol_0_image_class_info.csv with 10000 entries.
# File not found: payload_csv/split/dns/dns_4.csv
# train_data/protocol_0_image_class_info.csv has 10000 entries.
# Processing payload_csv/split/http/http_1.csv, Total rows: 5000
# Processing payload_csv/split/http/http_2.csv, Total rows: 5000
# Processing payload_csv/split/http/http_3.csv, Total rows: 5000
# Processing payload_csv/split/http/http_4.csv, Total rows: 5000
# Processing payload_csv/split/http/http_5.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 500 entries.
# Processing payload_csv/split/http/http_6.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 500 entries.
# Processing payload_csv/split/http/http_7.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 500 entries.
# Processing payload_csv/split/http/http_8.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 500 entries.
# Processing payload_csv/split/http/http_9.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 500 entries.
# Processing payload_csv/split/http/http_10.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 1000 entries.
# Processing payload_csv/split/http/http_11.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 1000 entries.
# Processing payload_csv/split/http/http_12.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 1000 entries.
# Processing payload_csv/split/http/http_13.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 1000 entries.
# Processing payload_csv/split/http/http_14.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 1000 entries.
# Processing payload_csv/split/http/http_15.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 1500 entries.
# Processing payload_csv/split/http/http_16.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 1500 entries.
# Processing payload_csv/split/http/http_17.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 1500 entries.
# Processing payload_csv/split/http/http_18.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 1500 entries.
# Processing payload_csv/split/http/http_19.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 1500 entries.
# Processing payload_csv/split/http/http_20.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 2000 entries.
# Processing payload_csv/split/http/http_21.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 2000 entries.
# Processing payload_csv/split/http/http_22.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 2000 entries.
# Processing payload_csv/split/http/http_23.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 2000 entries.
# Processing payload_csv/split/http/http_24.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 2000 entries.
# Processing payload_csv/split/http/http_25.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 2500 entries.
# Processing payload_csv/split/http/http_26.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 2500 entries.
# Processing payload_csv/split/http/http_27.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 2500 entries.
# Processing payload_csv/split/http/http_28.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 2500 entries.
# Processing payload_csv/split/http/http_29.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 2500 entries.
# Processing payload_csv/split/http/http_30.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 3000 entries.
# Processing payload_csv/split/http/http_31.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 3000 entries.
# Processing payload_csv/split/http/http_32.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 3000 entries.
# Processing payload_csv/split/http/http_33.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 3000 entries.
# Processing payload_csv/split/http/http_34.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 3000 entries.
# Processing payload_csv/split/http/http_35.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 3500 entries.
# Processing payload_csv/split/http/http_36.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 3500 entries.
# Processing payload_csv/split/http/http_37.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 3500 entries.
# Processing payload_csv/split/http/http_38.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 3500 entries.
# Processing payload_csv/split/http/http_39.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 3500 entries.
# Processing payload_csv/split/http/http_40.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 4000 entries.
# Processing payload_csv/split/http/http_41.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 4000 entries.
# Processing payload_csv/split/http/http_42.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 4000 entries.
# Processing payload_csv/split/http/http_43.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 4000 entries.
# Processing payload_csv/split/http/http_44.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 4000 entries.
# Processing payload_csv/split/http/http_45.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 4500 entries.
# Processing payload_csv/split/http/http_46.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 4500 entries.
# Processing payload_csv/split/http/http_47.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 4500 entries.
# Processing payload_csv/split/http/http_48.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 4500 entries.
# Processing payload_csv/split/http/http_49.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 4500 entries.
# Processing payload_csv/split/http/http_50.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 5000 entries.
# Processing payload_csv/split/http/http_51.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 5000 entries.
# Processing payload_csv/split/http/http_52.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 5000 entries.
# Processing payload_csv/split/http/http_53.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 5000 entries.
# Processing payload_csv/split/http/http_54.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 5000 entries.
# Processing payload_csv/split/http/http_55.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 5500 entries.
# Processing payload_csv/split/http/http_56.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 5500 entries.
# Processing payload_csv/split/http/http_57.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 5500 entries.
# Processing payload_csv/split/http/http_58.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 5500 entries.
# Processing payload_csv/split/http/http_59.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 5500 entries.
# Processing payload_csv/split/http/http_60.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 6000 entries.
# Processing payload_csv/split/http/http_61.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 6000 entries.
# Processing payload_csv/split/http/http_62.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 6000 entries.
# Processing payload_csv/split/http/http_63.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 6000 entries.
# Processing payload_csv/split/http/http_64.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 6000 entries.
# Processing payload_csv/split/http/http_65.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 6500 entries.
# Processing payload_csv/split/http/http_66.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 6500 entries.
# Processing payload_csv/split/http/http_67.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 6500 entries.
# Processing payload_csv/split/http/http_68.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 6500 entries.
# Processing payload_csv/split/http/http_69.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 6500 entries.
# Processing payload_csv/split/http/http_70.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 7000 entries.
# Processing payload_csv/split/http/http_71.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 7000 entries.
# Processing payload_csv/split/http/http_72.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 7000 entries.
# Processing payload_csv/split/http/http_73.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 7000 entries.
# Processing payload_csv/split/http/http_74.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 7000 entries.
# Processing payload_csv/split/http/http_75.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 7500 entries.
# Processing payload_csv/split/http/http_76.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 7500 entries.
# Processing payload_csv/split/http/http_77.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 7500 entries.
# Processing payload_csv/split/http/http_78.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 7500 entries.
# Processing payload_csv/split/http/http_79.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 7500 entries.
# Processing payload_csv/split/http/http_80.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 8000 entries.
# Processing payload_csv/split/http/http_81.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 8000 entries.
# Processing payload_csv/split/http/http_82.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 8000 entries.
# Processing payload_csv/split/http/http_83.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 8000 entries.
# Processing payload_csv/split/http/http_84.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 8000 entries.
# Processing payload_csv/split/http/http_85.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 8500 entries.
# Processing payload_csv/split/http/http_86.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 8500 entries.
# Processing payload_csv/split/http/http_87.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 8500 entries.
# Processing payload_csv/split/http/http_88.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 8500 entries.
# Processing payload_csv/split/http/http_89.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 8500 entries.
# Processing payload_csv/split/http/http_90.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 9000 entries.
# Processing payload_csv/split/http/http_91.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 9000 entries.
# Processing payload_csv/split/http/http_92.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 9000 entries.
# Processing payload_csv/split/http/http_93.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 9000 entries.
# Processing payload_csv/split/http/http_94.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 9000 entries.
# Processing payload_csv/split/http/http_95.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 9500 entries.
# Processing payload_csv/split/http/http_96.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 9500 entries.
# Processing payload_csv/split/http/http_97.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 9500 entries.
# Processing payload_csv/split/http/http_98.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 9500 entries.
# Processing payload_csv/split/http/http_99.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 9500 entries.
# Processing payload_csv/split/http/http_100.csv, Total rows: 5000
# Saved train_data/protocol_1_image_class_info.csv with 10000 entries.
# Processing payload_csv/split/http/http_101.csv, Total rows: 2658
# Saved train_data/protocol_1_image_class_info.csv with 10000 entries.
# File not found: payload_csv/split/http/http_102.csv
# train_data/protocol_1_image_class_info.csv has 10000 entries.
# Processing payload_csv/split/mqtt/mqtt_1.csv, Total rows: 5000
# Processing payload_csv/split/mqtt/mqtt_2.csv, Total rows: 5000
# Processing payload_csv/split/mqtt/mqtt_3.csv, Total rows: 5000
# Processing payload_csv/split/mqtt/mqtt_4.csv, Total rows: 5000
# Processing payload_csv/split/mqtt/mqtt_5.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 125 entries.
# Processing payload_csv/split/mqtt/mqtt_6.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 125 entries.
# Processing payload_csv/split/mqtt/mqtt_7.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 125 entries.
# Processing payload_csv/split/mqtt/mqtt_8.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 125 entries.
# Processing payload_csv/split/mqtt/mqtt_9.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 125 entries.
# Processing payload_csv/split/mqtt/mqtt_10.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 250 entries.
# Processing payload_csv/split/mqtt/mqtt_11.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 250 entries.
# Processing payload_csv/split/mqtt/mqtt_12.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 250 entries.
# Processing payload_csv/split/mqtt/mqtt_13.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 250 entries.
# Processing payload_csv/split/mqtt/mqtt_14.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 250 entries.
# Processing payload_csv/split/mqtt/mqtt_15.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 375 entries.
# Processing payload_csv/split/mqtt/mqtt_16.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 375 entries.
# Processing payload_csv/split/mqtt/mqtt_17.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 375 entries.
# Processing payload_csv/split/mqtt/mqtt_18.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 375 entries.
# Processing payload_csv/split/mqtt/mqtt_19.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 375 entries.
# Processing payload_csv/split/mqtt/mqtt_20.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 500 entries.
# Processing payload_csv/split/mqtt/mqtt_21.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 500 entries.
# Processing payload_csv/split/mqtt/mqtt_22.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 500 entries.
# Processing payload_csv/split/mqtt/mqtt_23.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 500 entries.
# Processing payload_csv/split/mqtt/mqtt_24.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 500 entries.
# Processing payload_csv/split/mqtt/mqtt_25.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 625 entries.
# Processing payload_csv/split/mqtt/mqtt_26.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 625 entries.
# Processing payload_csv/split/mqtt/mqtt_27.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 625 entries.
# Processing payload_csv/split/mqtt/mqtt_28.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 625 entries.
# Processing payload_csv/split/mqtt/mqtt_29.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 625 entries.
# Processing payload_csv/split/mqtt/mqtt_30.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 750 entries.
# Processing payload_csv/split/mqtt/mqtt_31.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 750 entries.
# Processing payload_csv/split/mqtt/mqtt_32.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 750 entries.
# Processing payload_csv/split/mqtt/mqtt_33.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 750 entries.
# Processing payload_csv/split/mqtt/mqtt_34.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 750 entries.
# Processing payload_csv/split/mqtt/mqtt_35.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 875 entries.
# Processing payload_csv/split/mqtt/mqtt_36.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 875 entries.
# Processing payload_csv/split/mqtt/mqtt_37.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 875 entries.
# Processing payload_csv/split/mqtt/mqtt_38.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 875 entries.
# Processing payload_csv/split/mqtt/mqtt_39.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 875 entries.
# Processing payload_csv/split/mqtt/mqtt_40.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1000 entries.
# Processing payload_csv/split/mqtt/mqtt_41.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1000 entries.
# Processing payload_csv/split/mqtt/mqtt_42.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1000 entries.
# Processing payload_csv/split/mqtt/mqtt_43.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1000 entries.
# Processing payload_csv/split/mqtt/mqtt_44.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1000 entries.
# Processing payload_csv/split/mqtt/mqtt_45.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1125 entries.
# Processing payload_csv/split/mqtt/mqtt_46.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1125 entries.
# Processing payload_csv/split/mqtt/mqtt_47.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1125 entries.
# Processing payload_csv/split/mqtt/mqtt_48.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1125 entries.
# Processing payload_csv/split/mqtt/mqtt_49.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1125 entries.
# Processing payload_csv/split/mqtt/mqtt_50.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1250 entries.
# Processing payload_csv/split/mqtt/mqtt_51.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1250 entries.
# Processing payload_csv/split/mqtt/mqtt_52.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1250 entries.
# Processing payload_csv/split/mqtt/mqtt_53.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1250 entries.
# Processing payload_csv/split/mqtt/mqtt_54.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1250 entries.
# Processing payload_csv/split/mqtt/mqtt_55.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1375 entries.
# Processing payload_csv/split/mqtt/mqtt_56.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1375 entries.
# Processing payload_csv/split/mqtt/mqtt_57.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1375 entries.
# Processing payload_csv/split/mqtt/mqtt_58.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1375 entries.
# Processing payload_csv/split/mqtt/mqtt_59.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1375 entries.
# Processing payload_csv/split/mqtt/mqtt_60.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1500 entries.
# Processing payload_csv/split/mqtt/mqtt_61.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1500 entries.
# Processing payload_csv/split/mqtt/mqtt_62.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1500 entries.
# Processing payload_csv/split/mqtt/mqtt_63.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1500 entries.
# Processing payload_csv/split/mqtt/mqtt_64.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1500 entries.
# Processing payload_csv/split/mqtt/mqtt_65.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1625 entries.
# Processing payload_csv/split/mqtt/mqtt_66.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1625 entries.
# Processing payload_csv/split/mqtt/mqtt_67.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1625 entries.
# Processing payload_csv/split/mqtt/mqtt_68.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1625 entries.
# Processing payload_csv/split/mqtt/mqtt_69.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1625 entries.
# Processing payload_csv/split/mqtt/mqtt_70.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1750 entries.
# Processing payload_csv/split/mqtt/mqtt_71.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1750 entries.
# Processing payload_csv/split/mqtt/mqtt_72.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1750 entries.
# Processing payload_csv/split/mqtt/mqtt_73.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1750 entries.
# Processing payload_csv/split/mqtt/mqtt_74.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1750 entries.
# Processing payload_csv/split/mqtt/mqtt_75.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1875 entries.
# Processing payload_csv/split/mqtt/mqtt_76.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1875 entries.
# Processing payload_csv/split/mqtt/mqtt_77.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1875 entries.
# Processing payload_csv/split/mqtt/mqtt_78.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1875 entries.
# Processing payload_csv/split/mqtt/mqtt_79.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 1875 entries.
# Processing payload_csv/split/mqtt/mqtt_80.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2000 entries.
# Processing payload_csv/split/mqtt/mqtt_81.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2000 entries.
# Processing payload_csv/split/mqtt/mqtt_82.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2000 entries.
# Processing payload_csv/split/mqtt/mqtt_83.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2000 entries.
# Processing payload_csv/split/mqtt/mqtt_84.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2000 entries.
# Processing payload_csv/split/mqtt/mqtt_85.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2125 entries.
# Processing payload_csv/split/mqtt/mqtt_86.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2125 entries.
# Processing payload_csv/split/mqtt/mqtt_87.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2125 entries.
# Processing payload_csv/split/mqtt/mqtt_88.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2125 entries.
# Processing payload_csv/split/mqtt/mqtt_89.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2125 entries.
# Processing payload_csv/split/mqtt/mqtt_90.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2250 entries.
# Processing payload_csv/split/mqtt/mqtt_91.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2250 entries.
# Processing payload_csv/split/mqtt/mqtt_92.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2250 entries.
# Processing payload_csv/split/mqtt/mqtt_93.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2250 entries.
# Processing payload_csv/split/mqtt/mqtt_94.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2250 entries.
# Processing payload_csv/split/mqtt/mqtt_95.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2375 entries.
# Processing payload_csv/split/mqtt/mqtt_96.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2375 entries.
# Processing payload_csv/split/mqtt/mqtt_97.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2375 entries.
# Processing payload_csv/split/mqtt/mqtt_98.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2375 entries.
# Processing payload_csv/split/mqtt/mqtt_99.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2375 entries.
# Processing payload_csv/split/mqtt/mqtt_100.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2500 entries.
# Processing payload_csv/split/mqtt/mqtt_101.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2500 entries.
# Processing payload_csv/split/mqtt/mqtt_102.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2500 entries.
# Processing payload_csv/split/mqtt/mqtt_103.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2500 entries.
# Processing payload_csv/split/mqtt/mqtt_104.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2500 entries.
# Processing payload_csv/split/mqtt/mqtt_105.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2625 entries.
# Processing payload_csv/split/mqtt/mqtt_106.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2625 entries.
# Processing payload_csv/split/mqtt/mqtt_107.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2625 entries.
# Processing payload_csv/split/mqtt/mqtt_108.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2625 entries.
# Processing payload_csv/split/mqtt/mqtt_109.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2625 entries.
# Processing payload_csv/split/mqtt/mqtt_110.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2750 entries.
# Processing payload_csv/split/mqtt/mqtt_111.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2750 entries.
# Processing payload_csv/split/mqtt/mqtt_112.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2750 entries.
# Processing payload_csv/split/mqtt/mqtt_113.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2750 entries.
# Processing payload_csv/split/mqtt/mqtt_114.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2750 entries.
# Processing payload_csv/split/mqtt/mqtt_115.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2875 entries.
# Processing payload_csv/split/mqtt/mqtt_116.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2875 entries.
# Processing payload_csv/split/mqtt/mqtt_117.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2875 entries.
# Processing payload_csv/split/mqtt/mqtt_118.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2875 entries.
# Processing payload_csv/split/mqtt/mqtt_119.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 2875 entries.
# Processing payload_csv/split/mqtt/mqtt_120.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3000 entries.
# Processing payload_csv/split/mqtt/mqtt_121.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3000 entries.
# Processing payload_csv/split/mqtt/mqtt_122.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3000 entries.
# Processing payload_csv/split/mqtt/mqtt_123.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3000 entries.
# Processing payload_csv/split/mqtt/mqtt_124.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3000 entries.
# Processing payload_csv/split/mqtt/mqtt_125.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3125 entries.
# Processing payload_csv/split/mqtt/mqtt_126.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3125 entries.
# Processing payload_csv/split/mqtt/mqtt_127.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3125 entries.
# Processing payload_csv/split/mqtt/mqtt_128.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3125 entries.
# Processing payload_csv/split/mqtt/mqtt_129.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3125 entries.
# Processing payload_csv/split/mqtt/mqtt_130.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3250 entries.
# Processing payload_csv/split/mqtt/mqtt_131.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3250 entries.
# Processing payload_csv/split/mqtt/mqtt_132.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3250 entries.
# Processing payload_csv/split/mqtt/mqtt_133.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3250 entries.
# Processing payload_csv/split/mqtt/mqtt_134.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3250 entries.
# Processing payload_csv/split/mqtt/mqtt_135.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3375 entries.
# Processing payload_csv/split/mqtt/mqtt_136.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3375 entries.
# Processing payload_csv/split/mqtt/mqtt_137.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3375 entries.
# Processing payload_csv/split/mqtt/mqtt_138.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3375 entries.
# Processing payload_csv/split/mqtt/mqtt_139.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3375 entries.
# Processing payload_csv/split/mqtt/mqtt_140.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3500 entries.
# Processing payload_csv/split/mqtt/mqtt_141.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3500 entries.
# Processing payload_csv/split/mqtt/mqtt_142.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3500 entries.
# Processing payload_csv/split/mqtt/mqtt_143.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3500 entries.
# Processing payload_csv/split/mqtt/mqtt_144.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3500 entries.
# Processing payload_csv/split/mqtt/mqtt_145.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3625 entries.
# Processing payload_csv/split/mqtt/mqtt_146.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3625 entries.
# Processing payload_csv/split/mqtt/mqtt_147.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3625 entries.
# Processing payload_csv/split/mqtt/mqtt_148.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3625 entries.
# Processing payload_csv/split/mqtt/mqtt_149.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3625 entries.
# Processing payload_csv/split/mqtt/mqtt_150.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3750 entries.
# Processing payload_csv/split/mqtt/mqtt_151.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3750 entries.
# Processing payload_csv/split/mqtt/mqtt_152.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3750 entries.
# Processing payload_csv/split/mqtt/mqtt_153.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3750 entries.
# Processing payload_csv/split/mqtt/mqtt_154.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3750 entries.
# Processing payload_csv/split/mqtt/mqtt_155.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3875 entries.
# Processing payload_csv/split/mqtt/mqtt_156.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3875 entries.
# Processing payload_csv/split/mqtt/mqtt_157.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3875 entries.
# Processing payload_csv/split/mqtt/mqtt_158.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3875 entries.
# Processing payload_csv/split/mqtt/mqtt_159.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 3875 entries.
# Processing payload_csv/split/mqtt/mqtt_160.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4000 entries.
# Processing payload_csv/split/mqtt/mqtt_161.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4000 entries.
# Processing payload_csv/split/mqtt/mqtt_162.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4000 entries.
# Processing payload_csv/split/mqtt/mqtt_163.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4000 entries.
# Processing payload_csv/split/mqtt/mqtt_164.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4000 entries.
# Processing payload_csv/split/mqtt/mqtt_165.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4125 entries.
# Processing payload_csv/split/mqtt/mqtt_166.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4125 entries.
# Processing payload_csv/split/mqtt/mqtt_167.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4125 entries.
# Processing payload_csv/split/mqtt/mqtt_168.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4125 entries.
# Processing payload_csv/split/mqtt/mqtt_169.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4125 entries.
# Processing payload_csv/split/mqtt/mqtt_170.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4250 entries.
# Processing payload_csv/split/mqtt/mqtt_171.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4250 entries.
# Processing payload_csv/split/mqtt/mqtt_172.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4250 entries.
# Processing payload_csv/split/mqtt/mqtt_173.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4250 entries.
# Processing payload_csv/split/mqtt/mqtt_174.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4250 entries.
# Processing payload_csv/split/mqtt/mqtt_175.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4375 entries.
# Processing payload_csv/split/mqtt/mqtt_176.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4375 entries.
# Processing payload_csv/split/mqtt/mqtt_177.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4375 entries.
# Processing payload_csv/split/mqtt/mqtt_178.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4375 entries.
# Processing payload_csv/split/mqtt/mqtt_179.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4375 entries.
# Processing payload_csv/split/mqtt/mqtt_180.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4500 entries.
# Processing payload_csv/split/mqtt/mqtt_181.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4500 entries.
# Processing payload_csv/split/mqtt/mqtt_182.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4500 entries.
# Processing payload_csv/split/mqtt/mqtt_183.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4500 entries.
# Processing payload_csv/split/mqtt/mqtt_184.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4500 entries.
# Processing payload_csv/split/mqtt/mqtt_185.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4625 entries.
# Processing payload_csv/split/mqtt/mqtt_186.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4625 entries.
# Processing payload_csv/split/mqtt/mqtt_187.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4625 entries.
# Processing payload_csv/split/mqtt/mqtt_188.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4625 entries.
# Processing payload_csv/split/mqtt/mqtt_189.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4625 entries.
# Processing payload_csv/split/mqtt/mqtt_190.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4750 entries.
# Processing payload_csv/split/mqtt/mqtt_191.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4750 entries.
# Processing payload_csv/split/mqtt/mqtt_192.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4750 entries.
# Processing payload_csv/split/mqtt/mqtt_193.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4750 entries.
# Processing payload_csv/split/mqtt/mqtt_194.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4750 entries.
# Processing payload_csv/split/mqtt/mqtt_195.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4875 entries.
# Processing payload_csv/split/mqtt/mqtt_196.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4875 entries.
# Processing payload_csv/split/mqtt/mqtt_197.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4875 entries.
# Processing payload_csv/split/mqtt/mqtt_198.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4875 entries.
# Processing payload_csv/split/mqtt/mqtt_199.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 4875 entries.
# Processing payload_csv/split/mqtt/mqtt_200.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5000 entries.
# Processing payload_csv/split/mqtt/mqtt_201.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5000 entries.
# Processing payload_csv/split/mqtt/mqtt_202.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5000 entries.
# Processing payload_csv/split/mqtt/mqtt_203.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5000 entries.
# Processing payload_csv/split/mqtt/mqtt_204.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5000 entries.
# Processing payload_csv/split/mqtt/mqtt_205.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5125 entries.
# Processing payload_csv/split/mqtt/mqtt_206.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5125 entries.
# Processing payload_csv/split/mqtt/mqtt_207.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5125 entries.
# Processing payload_csv/split/mqtt/mqtt_208.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5125 entries.
# Processing payload_csv/split/mqtt/mqtt_209.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5125 entries.
# Processing payload_csv/split/mqtt/mqtt_210.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5250 entries.
# Processing payload_csv/split/mqtt/mqtt_211.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5250 entries.
# Processing payload_csv/split/mqtt/mqtt_212.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5250 entries.
# Processing payload_csv/split/mqtt/mqtt_213.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5250 entries.
# Processing payload_csv/split/mqtt/mqtt_214.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5250 entries.
# Processing payload_csv/split/mqtt/mqtt_215.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5375 entries.
# Processing payload_csv/split/mqtt/mqtt_216.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5375 entries.
# Processing payload_csv/split/mqtt/mqtt_217.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5375 entries.
# Processing payload_csv/split/mqtt/mqtt_218.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5375 entries.
# Processing payload_csv/split/mqtt/mqtt_219.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5375 entries.
# Processing payload_csv/split/mqtt/mqtt_220.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5500 entries.
# Processing payload_csv/split/mqtt/mqtt_221.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5500 entries.
# Processing payload_csv/split/mqtt/mqtt_222.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5500 entries.
# Processing payload_csv/split/mqtt/mqtt_223.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5500 entries.
# Processing payload_csv/split/mqtt/mqtt_224.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5500 entries.
# Processing payload_csv/split/mqtt/mqtt_225.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5625 entries.
# Processing payload_csv/split/mqtt/mqtt_226.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5625 entries.
# Processing payload_csv/split/mqtt/mqtt_227.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5625 entries.
# Processing payload_csv/split/mqtt/mqtt_228.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5625 entries.
# Processing payload_csv/split/mqtt/mqtt_229.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5625 entries.
# Processing payload_csv/split/mqtt/mqtt_230.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5750 entries.
# Processing payload_csv/split/mqtt/mqtt_231.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5750 entries.
# Processing payload_csv/split/mqtt/mqtt_232.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5750 entries.
# Processing payload_csv/split/mqtt/mqtt_233.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5750 entries.
# Processing payload_csv/split/mqtt/mqtt_234.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5750 entries.
# Processing payload_csv/split/mqtt/mqtt_235.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5875 entries.
# Processing payload_csv/split/mqtt/mqtt_236.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5875 entries.
# Processing payload_csv/split/mqtt/mqtt_237.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5875 entries.
# Processing payload_csv/split/mqtt/mqtt_238.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5875 entries.
# Processing payload_csv/split/mqtt/mqtt_239.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 5875 entries.
# Processing payload_csv/split/mqtt/mqtt_240.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6000 entries.
# Processing payload_csv/split/mqtt/mqtt_241.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6000 entries.
# Processing payload_csv/split/mqtt/mqtt_242.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6000 entries.
# Processing payload_csv/split/mqtt/mqtt_243.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6000 entries.
# Processing payload_csv/split/mqtt/mqtt_244.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6000 entries.
# Processing payload_csv/split/mqtt/mqtt_245.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6125 entries.
# Processing payload_csv/split/mqtt/mqtt_246.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6125 entries.
# Processing payload_csv/split/mqtt/mqtt_247.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6125 entries.
# Processing payload_csv/split/mqtt/mqtt_248.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6125 entries.
# Processing payload_csv/split/mqtt/mqtt_249.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6125 entries.
# Processing payload_csv/split/mqtt/mqtt_250.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6250 entries.
# Processing payload_csv/split/mqtt/mqtt_251.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6250 entries.
# Processing payload_csv/split/mqtt/mqtt_252.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6250 entries.
# Processing payload_csv/split/mqtt/mqtt_253.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6250 entries.
# Processing payload_csv/split/mqtt/mqtt_254.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6250 entries.
# Processing payload_csv/split/mqtt/mqtt_255.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6375 entries.
# Processing payload_csv/split/mqtt/mqtt_256.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6375 entries.
# Processing payload_csv/split/mqtt/mqtt_257.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6375 entries.
# Processing payload_csv/split/mqtt/mqtt_258.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6375 entries.
# Processing payload_csv/split/mqtt/mqtt_259.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6375 entries.
# Processing payload_csv/split/mqtt/mqtt_260.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6500 entries.
# Processing payload_csv/split/mqtt/mqtt_261.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 6500 entries.
# ...
# Saved train_data/protocol_2_image_class_info.csv with 7000 entries.
# Processing payload_csv/split/mqtt/mqtt_284.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7000 entries.
# Processing payload_csv/split/mqtt/mqtt_285.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7125 entries.
# Processing payload_csv/split/mqtt/mqtt_286.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7125 entries.
# Processing payload_csv/split/mqtt/mqtt_287.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7125 entries.
# Processing payload_csv/split/mqtt/mqtt_288.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7125 entries.
# Processing payload_csv/split/mqtt/mqtt_289.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7125 entries.
# Processing payload_csv/split/mqtt/mqtt_290.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7250 entries.
# Processing payload_csv/split/mqtt/mqtt_291.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7250 entries.
# Processing payload_csv/split/mqtt/mqtt_292.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7250 entries.
# Processing payload_csv/split/mqtt/mqtt_293.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7250 entries.
# Processing payload_csv/split/mqtt/mqtt_294.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7250 entries.
# Processing payload_csv/split/mqtt/mqtt_295.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7375 entries.
# Processing payload_csv/split/mqtt/mqtt_296.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7375 entries.
# Processing payload_csv/split/mqtt/mqtt_297.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7375 entries.
# Processing payload_csv/split/mqtt/mqtt_298.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7375 entries.
# Processing payload_csv/split/mqtt/mqtt_299.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7375 entries.
# Processing payload_csv/split/mqtt/mqtt_300.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7500 entries.
# Processing payload_csv/split/mqtt/mqtt_301.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7500 entries.
# Processing payload_csv/split/mqtt/mqtt_302.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7500 entries.
# Processing payload_csv/split/mqtt/mqtt_303.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7500 entries.
# Processing payload_csv/split/mqtt/mqtt_304.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7500 entries.
# Processing payload_csv/split/mqtt/mqtt_305.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7625 entries.
# Processing payload_csv/split/mqtt/mqtt_306.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7625 entries.
# Processing payload_csv/split/mqtt/mqtt_307.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7625 entries.
# Processing payload_csv/split/mqtt/mqtt_308.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7625 entries.
# Processing payload_csv/split/mqtt/mqtt_309.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7625 entries.
# Processing payload_csv/split/mqtt/mqtt_310.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7750 entries.
# Processing payload_csv/split/mqtt/mqtt_311.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7750 entries.
# Processing payload_csv/split/mqtt/mqtt_312.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7750 entries.
# Processing payload_csv/split/mqtt/mqtt_313.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7750 entries.
# Processing payload_csv/split/mqtt/mqtt_314.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7750 entries.
# Processing payload_csv/split/mqtt/mqtt_315.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7875 entries.
# Processing payload_csv/split/mqtt/mqtt_316.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7875 entries.
# Processing payload_csv/split/mqtt/mqtt_317.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7875 entries.
# Processing payload_csv/split/mqtt/mqtt_318.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7875 entries.
# Processing payload_csv/split/mqtt/mqtt_319.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 7875 entries.
# Processing payload_csv/split/mqtt/mqtt_320.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8000 entries.
# Processing payload_csv/split/mqtt/mqtt_321.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8000 entries.
# Processing payload_csv/split/mqtt/mqtt_322.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8000 entries.
# Processing payload_csv/split/mqtt/mqtt_323.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8000 entries.
# Processing payload_csv/split/mqtt/mqtt_324.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8000 entries.
# Processing payload_csv/split/mqtt/mqtt_325.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8125 entries.
# Processing payload_csv/split/mqtt/mqtt_326.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8125 entries.
# Processing payload_csv/split/mqtt/mqtt_327.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8125 entries.
# Processing payload_csv/split/mqtt/mqtt_328.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8125 entries.
# Processing payload_csv/split/mqtt/mqtt_329.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8125 entries.
# Processing payload_csv/split/mqtt/mqtt_330.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8250 entries.
# Processing payload_csv/split/mqtt/mqtt_331.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8250 entries.
# Processing payload_csv/split/mqtt/mqtt_332.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8250 entries.
# Processing payload_csv/split/mqtt/mqtt_333.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8250 entries.
# Processing payload_csv/split/mqtt/mqtt_334.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8250 entries.
# Processing payload_csv/split/mqtt/mqtt_335.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8375 entries.
# Processing payload_csv/split/mqtt/mqtt_336.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8375 entries.
# Processing payload_csv/split/mqtt/mqtt_337.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8375 entries.
# Processing payload_csv/split/mqtt/mqtt_338.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8375 entries.
# Processing payload_csv/split/mqtt/mqtt_339.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8375 entries.
# Processing payload_csv/split/mqtt/mqtt_340.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8500 entries.
# Processing payload_csv/split/mqtt/mqtt_341.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8500 entries.
# Processing payload_csv/split/mqtt/mqtt_342.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8500 entries.
# Processing payload_csv/split/mqtt/mqtt_343.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8500 entries.
# Processing payload_csv/split/mqtt/mqtt_344.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8500 entries.
# Processing payload_csv/split/mqtt/mqtt_345.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8625 entries.
# Processing payload_csv/split/mqtt/mqtt_346.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8625 entries.
# Processing payload_csv/split/mqtt/mqtt_347.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8625 entries.
# Processing payload_csv/split/mqtt/mqtt_348.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8625 entries.
# Processing payload_csv/split/mqtt/mqtt_349.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8625 entries.
# Processing payload_csv/split/mqtt/mqtt_350.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8750 entries.
# Processing payload_csv/split/mqtt/mqtt_351.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8750 entries.
# Processing payload_csv/split/mqtt/mqtt_352.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8750 entries.
# Processing payload_csv/split/mqtt/mqtt_353.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8750 entries.
# Processing payload_csv/split/mqtt/mqtt_354.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8750 entries.
# Processing payload_csv/split/mqtt/mqtt_355.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8875 entries.
# Processing payload_csv/split/mqtt/mqtt_356.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8875 entries.
# Processing payload_csv/split/mqtt/mqtt_357.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8875 entries.
# Processing payload_csv/split/mqtt/mqtt_358.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8875 entries.
# Processing payload_csv/split/mqtt/mqtt_359.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 8875 entries.
# Processing payload_csv/split/mqtt/mqtt_360.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9000 entries.
# Processing payload_csv/split/mqtt/mqtt_361.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9000 entries.
# Processing payload_csv/split/mqtt/mqtt_362.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9000 entries.
# Processing payload_csv/split/mqtt/mqtt_363.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9000 entries.
# Processing payload_csv/split/mqtt/mqtt_364.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9000 entries.
# Processing payload_csv/split/mqtt/mqtt_365.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9125 entries.
# Processing payload_csv/split/mqtt/mqtt_366.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9125 entries.
# Processing payload_csv/split/mqtt/mqtt_367.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9125 entries.
# Processing payload_csv/split/mqtt/mqtt_368.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9125 entries.
# Processing payload_csv/split/mqtt/mqtt_369.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9125 entries.
# Processing payload_csv/split/mqtt/mqtt_370.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9250 entries.
# Processing payload_csv/split/mqtt/mqtt_371.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9250 entries.
# Processing payload_csv/split/mqtt/mqtt_372.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9250 entries.
# Processing payload_csv/split/mqtt/mqtt_373.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9250 entries.
# Processing payload_csv/split/mqtt/mqtt_374.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9250 entries.
# Processing payload_csv/split/mqtt/mqtt_375.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9375 entries.
# Processing payload_csv/split/mqtt/mqtt_376.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9375 entries.
# Processing payload_csv/split/mqtt/mqtt_377.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9375 entries.
# Processing payload_csv/split/mqtt/mqtt_378.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9375 entries.
# Processing payload_csv/split/mqtt/mqtt_379.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9375 entries.
# Processing payload_csv/split/mqtt/mqtt_380.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9500 entries.
# Processing payload_csv/split/mqtt/mqtt_381.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9500 entries.
# Processing payload_csv/split/mqtt/mqtt_382.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9500 entries.
# Processing payload_csv/split/mqtt/mqtt_383.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9500 entries.
# Processing payload_csv/split/mqtt/mqtt_384.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9500 entries.
# Processing payload_csv/split/mqtt/mqtt_385.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9625 entries.
# Processing payload_csv/split/mqtt/mqtt_386.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9625 entries.
# Processing payload_csv/split/mqtt/mqtt_387.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9625 entries.
# Processing payload_csv/split/mqtt/mqtt_388.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9625 entries.
# Processing payload_csv/split/mqtt/mqtt_389.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9625 entries.
# Processing payload_csv/split/mqtt/mqtt_390.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9750 entries.
# Processing payload_csv/split/mqtt/mqtt_391.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9750 entries.
# Processing payload_csv/split/mqtt/mqtt_392.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9750 entries.
# Processing payload_csv/split/mqtt/mqtt_393.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9750 entries.
# Processing payload_csv/split/mqtt/mqtt_394.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9750 entries.
# Processing payload_csv/split/mqtt/mqtt_395.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9875 entries.
# Processing payload_csv/split/mqtt/mqtt_396.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9875 entries.
# Processing payload_csv/split/mqtt/mqtt_397.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9875 entries.
# Processing payload_csv/split/mqtt/mqtt_398.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9875 entries.
# Processing payload_csv/split/mqtt/mqtt_399.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 9875 entries.
# Processing payload_csv/split/mqtt/mqtt_400.csv, Total rows: 5000
# Saved train_data/protocol_2_image_class_info.csv with 10000 entries.
# Processing payload_csv/split/mqtt/mqtt_401.csv, Total rows: 316
# Saved train_data/protocol_2_image_class_info.csv with 10000 entries.
# File not found: payload_csv/split/mqtt/mqtt_402.csv
# train_data/protocol_2_image_class_info.csv has 10000 entries.
# Saved train_data/all_payload_data_class_info.csv with 30000 entries.
